# %%
import pandas as pd 
import numpy as np 
import seaborn as sns

h = pd.read_csv('./sales_predictions.csv'); 
d = h[h['item_price']  < 300000].sample(50)
d['date'] = pd.to_datetime(d['date'])
sns.relplot(data=d ,x='date', y='item_price', height=4, aspect=2.7)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-5be1c6b89507> in <module>
#       6 d = h[h['item_price']  < 300000].sample(50)
#       7 d['date'] = pd.to_datetime(d['date'])
# ----> 8 sns.lineplot(data=d ,x='date', y='item_price', height=4, aspect=2.7)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...
