# %%
import pandas as pd 
import numpy as np 
import seaborn as sns

h = pd.read_csv('./IBM_HR_ATTRITION.csv')
sns.set_theme(style="ticks")
sns.catplot(x="Attrition", y="JobSatisfaction", hue="kind", data=h)
